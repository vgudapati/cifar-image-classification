# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [02:40, 1.06MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    y = np.zeros((len(x), 10))
    rows = range(len(x))
    cols = list(x)
    y[rows, cols] = 1
    return y



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shape = [None]
    shape.extend(image_shape)
    return tf.placeholder(tf.float32, shape=shape, name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None), name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # TODO: Implement Function
    # First the Weights and Biases
    w_shape = [conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs]
    stddev = np.sqrt(2/(conv_ksize[0] * conv_ksize[1] * x_tensor.get_shape().as_list()[3]))
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))
    biases = tf.Variable(tf.zeros([conv_num_outputs]))
    # Convolution
    convolution = tf.nn.conv2d(x_tensor, weights, [1,conv_strides[0],conv_strides[1],1], padding="SAME")
    # Add ReLU and bias
    relu = tf.nn.relu(tf.add(convolution,biases))
    # Max pooling
    k_size = [1, pool_ksize[0], pool_ksize[1],1]
    m_strides = [1, pool_strides[0], pool_strides[1],1]
    max_pool = tf.nn.max_pool(relu, ksize=k_size, strides=m_strides, padding="SAME")

    return max_pool

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()[1:]
    dim_flatt = shape[0]*shape[1]*shape[2]
    
    flatx = tf.reshape(x_tensor, [-1, dim_flatt])
    return flatx


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w_shape = [x_tensor.get_shape().as_list()[1], num_outputs]
    stddev = np.sqrt(2/x_tensor.get_shape().as_list()[1])
    
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), biases))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    # TODO: Implement Function
    w_shape = [x_tensor.get_shape().as_list()[1], num_outputs]
    stddev = np.sqrt(2/x_tensor.get_shape().as_list()[1])
    
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))

    
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.add(tf.matmul(x_tensor, weights), biases)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_dropout_prob = keep_prob / 2
    conv1 = conv2d_maxpool(x, 48, (3, 3), (1, 1), (2, 2), (2, 2))
    conv2 = conv2d_maxpool(conv1, 96, (3, 3), (1, 1), (2, 2), (2, 2))
    conv3 = conv2d_maxpool(conv2, 192, (3, 3), (1, 1), (2, 2), (2, 2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fconn = fully_conn(flat, 1024) 
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    fconn = fully_conn(fconn_w_dropout, 512)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    fconn = fully_conn(fconn_w_dropout, 256)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    result = output(fconn_w_dropout, 10)
    
    # TODO: return output
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.})
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    
    print('Epoch Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Epoch Loss:     2.1666 Validation Accuracy: 0.270400
# Epoch  2, CIFAR-10 Batch 1:  Epoch Loss:     1.8673 Validation Accuracy: 0.364400
# Epoch  3, CIFAR-10 Batch 1:  Epoch Loss:     1.6544 Validation Accuracy: 0.412600
# Epoch  4, CIFAR-10 Batch 1:  Epoch Loss:     1.4080 Validation Accuracy: 0.431400
# Epoch  5, CIFAR-10 Batch 1:  Epoch Loss:     1.2103 Validation Accuracy: 0.498200
# Epoch  6, CIFAR-10 Batch 1:  Epoch Loss:     1.0084 Validation Accuracy: 0.498200
# Epoch  7, CIFAR-10 Batch 1:  Epoch Loss:     0.6842 Validation Accuracy: 0.531200
# Epoch  8, CIFAR-10 Batch 1:  Epoch Loss:     0.4963 Validation Accuracy: 0.543000
# Epoch  9, CIFAR-10 Batch 1:  Epoch Loss:     0.4040 Validation Accuracy: 0.557200
# Epoch 10, CIFAR-10 Batch 1:  Epoch Loss:     0.2894 Validation Accuracy: 0.550800
# Epoch 11, CIFAR-10 Batch 1:  Epoch Loss:     0.1742 Validation Accuracy: 0.591200
# Epoch 12, CIFAR-10 Batch 1:  Epoch Loss:     0.1220 Validation Accuracy: 0.574200
# Epoch 13, CIFAR-10 Batch 1:  Epoch Loss:     0.0574 Validation Accuracy: 0.582800
# Epoch 14, CIFAR-10 Batch 1:  Epoch Loss:     0.0472 Validation Accuracy: 0.582600
# Epoch 15, CIFAR-10 Batch 1:  Epoch Loss:     0.0368 Validation Accuracy: 0.591000
# Epoch 16, CIFAR-10 Batch 1:  Epoch Loss:     0.0426 Validation Accuracy: 0.567600
# Epoch 17, CIFAR-10 Batch 1:  Epoch Loss:     0.0195 Validation Accuracy: 0.610800
# Epoch 18, CIFAR-10 Batch 1:  Epoch Loss:     0.0080 Validation Accuracy: 0.593600
# Epoch 19, CIFAR-10 Batch 1:  Epoch Loss:     0.0086 Validation Accuracy: 0.609600
# Epoch 20, CIFAR-10 Batch 1:  Epoch Loss:     0.0044 Validation Accuracy: 0.593000
# Epoch 21, CIFAR-10 Batch 1:  Epoch Loss:     0.0028 Validation Accuracy: 0.578200
# Epoch 22, CIFAR-10 Batch 1:  Epoch Loss:     0.0031 Validation Accuracy: 0.598200
# Epoch 23, CIFAR-10 Batch 1:  Epoch Loss:     0.0020 Validation Accuracy: 0.599400
# Epoch 24, CIFAR-10 Batch 1:  Epoch Loss:     0.0010 Validation Accuracy: 0.596400
# Epoch 25, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.581600
# Epoch 26, CIFAR-10 Batch 1:  Epoch Loss:     0.0012 Validation Accuracy: 0.595600
# Epoch 27, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.590200
# Epoch 28, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.615200
# Epoch 29, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.605600
# Epoch 30, CIFAR-10 Batch 1:  Epoch Loss:     0.0034 Validation Accuracy: 0.596800
# Epoch 31, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.605200
# Epoch 32, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.615000
# Epoch 33, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.611400
# Epoch 34, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.617600
# Epoch 35, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.614400
# Epoch 36, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.610600
# Epoch 37, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.614400
# Epoch 38, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.615000
# Epoch 39, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.618200
# Epoch 40, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.612000
# Epoch 41, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.614000
# Epoch 42, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.615600
# Epoch 43, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.621000
# Epoch 44, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.615800
# Epoch 45, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.618800
# Epoch 46, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.603800
# Epoch 47, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.617400
# Epoch 48, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.609600
# Epoch 49, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.613200
# Epoch 50, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.623000
# Epoch 51, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.608200
# Epoch 52, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.600000
# Epoch 53, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.608400
# Epoch 54, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.617800
# Epoch 55, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.609400
# Epoch 56, CIFAR-10 Batch 1:  Epoch Loss:     0.0005 Validation Accuracy: 0.620400
# Epoch 57, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622800
# Epoch 58, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.619000
# Epoch 59, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.620600
# Epoch 60, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.615600
# Epoch 61, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.600400
# Epoch 62, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.618200
# Epoch 63, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622000
# Epoch 64, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.610400
# Epoch 65, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.607800
# Epoch 66, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.606600
# Epoch 67, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.613200
# Epoch 68, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.627600
# Epoch 69, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.608400
# Epoch 70, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.616000
# Epoch 71, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.619000
# Epoch 72, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.610800
# Epoch 73, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.613400
# Epoch 74, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.612400
# Epoch 75, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.619200
# Epoch 76, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.627000
# Epoch 77, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.624400
# Epoch 78, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.616800
# Epoch 79, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.614600
# Epoch 80, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.613800
# Epoch 81, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.620000
# Epoch 82, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622400
# Epoch 83, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622200
# Epoch 84, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.612600
# Epoch 85, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.609800
# Epoch 86, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.603600
# Epoch 87, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622600
# Epoch 88, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.625000
# Epoch 89, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.620800
# Epoch 90, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.610400
# Epoch 91, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.624000
# Epoch 92, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.619200
# Epoch 93, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.620400
# Epoch 94, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.619200
# Epoch 95, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622200
# Epoch 96, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.620600
# Epoch 97, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.624600
# Epoch 98, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.606400
# Epoch 99, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.616800
# Epoch 100, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Epoch Loss:     2.0994 Validation Accuracy: 0.315800
# Epoch  1, CIFAR-10 Batch 2:  Epoch Loss:     1.6705 Validation Accuracy: 0.378600
# Epoch  1, CIFAR-10 Batch 3:  Epoch Loss:     1.3705 Validation Accuracy: 0.405600
# Epoch  1, CIFAR-10 Batch 4:  Epoch Loss:     1.4271 Validation Accuracy: 0.474800
# Epoch  1, CIFAR-10 Batch 5:  Epoch Loss:     1.2996 Validation Accuracy: 0.498400
# Epoch  2, CIFAR-10 Batch 1:  Epoch Loss:     1.3539 Validation Accuracy: 0.534200
# Epoch  2, CIFAR-10 Batch 2:  Epoch Loss:     0.9670 Validation Accuracy: 0.539000
# Epoch  2, CIFAR-10 Batch 3:  Epoch Loss:     0.8358 Validation Accuracy: 0.544400
# Epoch  2, CIFAR-10 Batch 4:  Epoch Loss:     0.9524 Validation Accuracy: 0.570600
# Epoch  2, CIFAR-10 Batch 5:  Epoch Loss:     0.8643 Validation Accuracy: 0.607200
# Epoch  3, CIFAR-10 Batch 1:  Epoch Loss:     0.9022 Validation Accuracy: 0.613600
# Epoch  3, CIFAR-10 Batch 2:  Epoch Loss:     0.5973 Validation Accuracy: 0.610400
# Epoch  3, CIFAR-10 Batch 3:  Epoch Loss:     0.5556 Validation Accuracy: 0.634200
# Epoch  3, CIFAR-10 Batch 4:  Epoch Loss:     0.6491 Validation Accuracy: 0.636000
# Epoch  3, CIFAR-10 Batch 5:  Epoch Loss:     0.5833 Validation Accuracy: 0.647600
# Epoch  4, CIFAR-10 Batch 1:  Epoch Loss:     0.5649 Validation Accuracy: 0.643000
# Epoch  4, CIFAR-10 Batch 2:  Epoch Loss:     0.3589 Validation Accuracy: 0.652800
# Epoch  4, CIFAR-10 Batch 3:  Epoch Loss:     0.3168 Validation Accuracy: 0.637400
# Epoch  4, CIFAR-10 Batch 4:  Epoch Loss:     0.4413 Validation Accuracy: 0.661600
# Epoch  4, CIFAR-10 Batch 5:  Epoch Loss:     0.3053 Validation Accuracy: 0.679200
# Epoch  5, CIFAR-10 Batch 1:  Epoch Loss:     0.4263 Validation Accuracy: 0.678000
# Epoch  5, CIFAR-10 Batch 2:  Epoch Loss:     0.2393 Validation Accuracy: 0.673200
# Epoch  5, CIFAR-10 Batch 3:  Epoch Loss:     0.1780 Validation Accuracy: 0.698200
# Epoch  5, CIFAR-10 Batch 4:  Epoch Loss:     0.3274 Validation Accuracy: 0.687200
# Epoch  5, CIFAR-10 Batch 5:  Epoch Loss:     0.2400 Validation Accuracy: 0.674800
# Epoch  6, CIFAR-10 Batch 1:  Epoch Loss:     0.2649 Validation Accuracy: 0.688400
# Epoch  6, CIFAR-10 Batch 2:  Epoch Loss:     0.1705 Validation Accuracy: 0.678200
# Epoch  6, CIFAR-10 Batch 3:  Epoch Loss:     0.1211 Validation Accuracy: 0.686600
# Epoch  6, CIFAR-10 Batch 4:  Epoch Loss:     0.2341 Validation Accuracy: 0.692400
# Epoch  6, CIFAR-10 Batch 5:  Epoch Loss:     0.1283 Validation Accuracy: 0.705800
# Epoch  7, CIFAR-10 Batch 1:  Epoch Loss:     0.1949 Validation Accuracy: 0.706600
# Epoch  7, CIFAR-10 Batch 2:  Epoch Loss:     0.1130 Validation Accuracy: 0.692000
# Epoch  7, CIFAR-10 Batch 3:  Epoch Loss:     0.0648 Validation Accuracy: 0.699200
# Epoch  7, CIFAR-10 Batch 4:  Epoch Loss:     0.1329 Validation Accuracy: 0.710000
# Epoch  7, CIFAR-10 Batch 5:  Epoch Loss:     0.0862 Validation Accuracy: 0.713200
# Epoch  8, CIFAR-10 Batch 1:  Epoch Loss:     0.0947 Validation Accuracy: 0.703000
# Epoch  8, CIFAR-10 Batch 2:  Epoch Loss:     0.0763 Validation Accuracy: 0.694800
# Epoch  8, CIFAR-10 Batch 3:  Epoch Loss:     0.0570 Validation Accuracy: 0.677200
# Epoch  8, CIFAR-10 Batch 4:  Epoch Loss:     0.0703 Validation Accuracy: 0.706400
# Epoch  8, CIFAR-10 Batch 5:  Epoch Loss:     0.0652 Validation Accuracy: 0.716200
# Epoch  9, CIFAR-10 Batch 1:  Epoch Loss:     0.0675 Validation Accuracy: 0.707200
# Epoch  9, CIFAR-10 Batch 2:  Epoch Loss:     0.0394 Validation Accuracy: 0.701000
# Epoch  9, CIFAR-10 Batch 3:  Epoch Loss:     0.0278 Validation Accuracy: 0.685400
# Epoch  9, CIFAR-10 Batch 4:  Epoch Loss:     0.0460 Validation Accuracy: 0.713800
# Epoch  9, CIFAR-10 Batch 5:  Epoch Loss:     0.0205 Validation Accuracy: 0.705600
# Epoch 10, CIFAR-10 Batch 1:  Epoch Loss:     0.0552 Validation Accuracy: 0.705200
# Epoch 10, CIFAR-10 Batch 2:  Epoch Loss:     0.0363 Validation Accuracy: 0.718400
# Epoch 10, CIFAR-10 Batch 3:  Epoch Loss:     0.0208 Validation Accuracy: 0.711800
# Epoch 10, CIFAR-10 Batch 4:  Epoch Loss:     0.0270 Validation Accuracy: 0.717000
# Epoch 10, CIFAR-10 Batch 5:  Epoch Loss:     0.0245 Validation Accuracy: 0.696400
# Epoch 11, CIFAR-10 Batch 1:  Epoch Loss:     0.0439 Validation Accuracy: 0.715000
# Epoch 11, CIFAR-10 Batch 2:  Epoch Loss:     0.0234 Validation Accuracy: 0.705000
# Epoch 11, CIFAR-10 Batch 3:  Epoch Loss:     0.0161 Validation Accuracy: 0.712400
# Epoch 11, CIFAR-10 Batch 4:  Epoch Loss:     0.0366 Validation Accuracy: 0.706400
# Epoch 11, CIFAR-10 Batch 5:  Epoch Loss:     0.0150 Validation Accuracy: 0.714200
# Epoch 12, CIFAR-10 Batch 1:  Epoch Loss:     0.0168 Validation Accuracy: 0.716800
# Epoch 12, CIFAR-10 Batch 2:  Epoch Loss:     0.0167 Validation Accuracy: 0.712000
# Epoch 12, CIFAR-10 Batch 3:  Epoch Loss:     0.0178 Validation Accuracy: 0.711800
# Epoch 12, CIFAR-10 Batch 4:  Epoch Loss:     0.0225 Validation Accuracy: 0.719800
# Epoch 12, CIFAR-10 Batch 5:  Epoch Loss:     0.0141 Validation Accuracy: 0.716800
# Epoch 13, CIFAR-10 Batch 1:  Epoch Loss:     0.0119 Validation Accuracy: 0.719000
# Epoch 13, CIFAR-10 Batch 2:  Epoch Loss:     0.0210 Validation Accuracy: 0.714400
# Epoch 13, CIFAR-10 Batch 3:  Epoch Loss:     0.0123 Validation Accuracy: 0.710200
# Epoch 13, CIFAR-10 Batch 4:  Epoch Loss:     0.0118 Validation Accuracy: 0.717200
# Epoch 13, CIFAR-10 Batch 5:  Epoch Loss:     0.0055 Validation Accuracy: 0.718800
# Epoch 14, CIFAR-10 Batch 1:  Epoch Loss:     0.0105 Validation Accuracy: 0.722000
# Epoch 14, CIFAR-10 Batch 2:  Epoch Loss:     0.0073 Validation Accuracy: 0.706600
# Epoch 14, CIFAR-10 Batch 3:  Epoch Loss:     0.0093 Validation Accuracy: 0.720400
# Epoch 14, CIFAR-10 Batch 4:  Epoch Loss:     0.0058 Validation Accuracy: 0.726200
# Epoch 14, CIFAR-10 Batch 5:  Epoch Loss:     0.0064 Validation Accuracy: 0.711400
# Epoch 15, CIFAR-10 Batch 1:  Epoch Loss:     0.0089 Validation Accuracy: 0.723400
# Epoch 15, CIFAR-10 Batch 2:  Epoch Loss:     0.0037 Validation Accuracy: 0.715000
# Epoch 15, CIFAR-10 Batch 3:  Epoch Loss:     0.0072 Validation Accuracy: 0.707000
# Epoch 15, CIFAR-10 Batch 4:  Epoch Loss:     0.0028 Validation Accuracy: 0.718800
# Epoch 15, CIFAR-10 Batch 5:  Epoch Loss:     0.0015 Validation Accuracy: 0.718600
# Epoch 16, CIFAR-10 Batch 1:  Epoch Loss:     0.0031 Validation Accuracy: 0.719800
# Epoch 16, CIFAR-10 Batch 2:  Epoch Loss:     0.0016 Validation Accuracy: 0.721400
# Epoch 16, CIFAR-10 Batch 3:  Epoch Loss:     0.0031 Validation Accuracy: 0.714000
# Epoch 16, CIFAR-10 Batch 4:  Epoch Loss:     0.0053 Validation Accuracy: 0.710000
# Epoch 16, CIFAR-10 Batch 5:  Epoch Loss:     0.0038 Validation Accuracy: 0.722000
# Epoch 17, CIFAR-10 Batch 1:  Epoch Loss:     0.0019 Validation Accuracy: 0.726800
# Epoch 17, CIFAR-10 Batch 2:  Epoch Loss:     0.0021 Validation Accuracy: 0.737200
# Epoch 17, CIFAR-10 Batch 3:  Epoch Loss:     0.0013 Validation Accuracy: 0.729000
# Epoch 17, CIFAR-10 Batch 4:  Epoch Loss:     0.0012 Validation Accuracy: 0.714400
# Epoch 17, CIFAR-10 Batch 5:  Epoch Loss:     0.0024 Validation Accuracy: 0.714000
# Epoch 18, CIFAR-10 Batch 1:  Epoch Loss:     0.0028 Validation Accuracy: 0.729200
# Epoch 18, CIFAR-10 Batch 2:  Epoch Loss:     0.0008 Validation Accuracy: 0.725600
# Epoch 18, CIFAR-10 Batch 3:  Epoch Loss:     0.0016 Validation Accuracy: 0.719600
# Epoch 18, CIFAR-10 Batch 4:  Epoch Loss:     0.0007 Validation Accuracy: 0.701800
# Epoch 18, CIFAR-10 Batch 5:  Epoch Loss:     0.0040 Validation Accuracy: 0.711000
# Epoch 19, CIFAR-10 Batch 1:  Epoch Loss:     0.0005 Validation Accuracy: 0.722600
# Epoch 19, CIFAR-10 Batch 2:  Epoch Loss:     0.0012 Validation Accuracy: 0.720200
# Epoch 19, CIFAR-10 Batch 3:  Epoch Loss:     0.0006 Validation Accuracy: 0.729000
# Epoch 19, CIFAR-10 Batch 4:  Epoch Loss:     0.0010 Validation Accuracy: 0.722200
# Epoch 19, CIFAR-10 Batch 5:  Epoch Loss:     0.0011 Validation Accuracy: 0.726800
# Epoch 20, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.733200
# Epoch 20, CIFAR-10 Batch 2:  Epoch Loss:     0.0014 Validation Accuracy: 0.729800
# Epoch 20, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.728800
# Epoch 20, CIFAR-10 Batch 4:  Epoch Loss:     0.0013 Validation Accuracy: 0.730400
# Epoch 20, CIFAR-10 Batch 5:  Epoch Loss:     0.0005 Validation Accuracy: 0.726800
# Epoch 21, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.724600
# Epoch 21, CIFAR-10 Batch 2:  Epoch Loss:     0.0065 Validation Accuracy: 0.718400
# Epoch 21, CIFAR-10 Batch 3:  Epoch Loss:     0.0009 Validation Accuracy: 0.718600
# Epoch 21, CIFAR-10 Batch 4:  Epoch Loss:     0.0036 Validation Accuracy: 0.730800
# Epoch 21, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.727200
# Epoch 22, CIFAR-10 Batch 1:  Epoch Loss:     0.0024 Validation Accuracy: 0.728600
# Epoch 22, CIFAR-10 Batch 2:  Epoch Loss:     0.0005 Validation Accuracy: 0.729800
# Epoch 22, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.726200
# Epoch 22, CIFAR-10 Batch 4:  Epoch Loss:     0.0004 Validation Accuracy: 0.728600
# Epoch 22, CIFAR-10 Batch 5:  Epoch Loss:     0.0010 Validation Accuracy: 0.720400
# Epoch 23, CIFAR-10 Batch 1:  Epoch Loss:     0.0013 Validation Accuracy: 0.725600
# Epoch 23, CIFAR-10 Batch 2:  Epoch Loss:     0.0013 Validation Accuracy: 0.728600
# Epoch 23, CIFAR-10 Batch 3:  Epoch Loss:     0.0006 Validation Accuracy: 0.730800
# Epoch 23, CIFAR-10 Batch 4:  Epoch Loss:     0.0019 Validation Accuracy: 0.727600
# Epoch 23, CIFAR-10 Batch 5:  Epoch Loss:     0.0005 Validation Accuracy: 0.736400
# Epoch 24, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.728000
# Epoch 24, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.727400
# Epoch 24, CIFAR-10 Batch 3:  Epoch Loss:     0.0004 Validation Accuracy: 0.728400
# Epoch 24, CIFAR-10 Batch 4:  Epoch Loss:     0.0026 Validation Accuracy: 0.724600
# Epoch 24, CIFAR-10 Batch 5:  Epoch Loss:     0.0017 Validation Accuracy: 0.731600
# Epoch 25, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.731000
# Epoch 25, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.730400
# Epoch 25, CIFAR-10 Batch 3:  Epoch Loss:     0.0004 Validation Accuracy: 0.730000
# Epoch 25, CIFAR-10 Batch 4:  Epoch Loss:     0.0009 Validation Accuracy: 0.730600
# Epoch 25, CIFAR-10 Batch 5:  Epoch Loss:     0.0055 Validation Accuracy: 0.725000
# Epoch 26, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.726800
# Epoch 26, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.727000
# Epoch 26, CIFAR-10 Batch 3:  Epoch Loss:     0.0005 Validation Accuracy: 0.718600
# Epoch 26, CIFAR-10 Batch 4:  Epoch Loss:     0.0019 Validation Accuracy: 0.730200
# Epoch 26, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.731600
# Epoch 27, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.727200
# Epoch 27, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.727200
# Epoch 27, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.739800
# Epoch 27, CIFAR-10 Batch 4:  Epoch Loss:     0.0010 Validation Accuracy: 0.726800
# Epoch 27, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.725200
# Epoch 28, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.728200
# Epoch 28, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.724800
# Epoch 28, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.716800
# Epoch 28, CIFAR-10 Batch 4:  Epoch Loss:     0.0010 Validation Accuracy: 0.729800
# Epoch 28, CIFAR-10 Batch 5:  Epoch Loss:     0.0030 Validation Accuracy: 0.729000
# Epoch 29, CIFAR-10 Batch 1:  Epoch Loss:     0.0012 Validation Accuracy: 0.717600
# Epoch 29, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.729600
# Epoch 29, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.723800
# Epoch 29, CIFAR-10 Batch 4:  Epoch Loss:     0.0028 Validation Accuracy: 0.727200
# Epoch 29, CIFAR-10 Batch 5:  Epoch Loss:     0.0008 Validation Accuracy: 0.729200
# Epoch 30, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.722200
# Epoch 30, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.729600
# Epoch 30, CIFAR-10 Batch 3:  Epoch Loss:     0.0016 Validation Accuracy: 0.725000
# Epoch 30, CIFAR-10 Batch 4:  Epoch Loss:     0.0005 Validation Accuracy: 0.729200
# Epoch 30, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.731000
# Epoch 31, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.725200
# Epoch 31, CIFAR-10 Batch 2:  Epoch Loss:     0.0007 Validation Accuracy: 0.730800
# Epoch 31, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.732000
# Epoch 31, CIFAR-10 Batch 4:  Epoch Loss:     0.0009 Validation Accuracy: 0.738200
# Epoch 31, CIFAR-10 Batch 5:  Epoch Loss:     0.0003 Validation Accuracy: 0.729200
# Epoch 32, CIFAR-10 Batch 1:  Epoch Loss:     0.0018 Validation Accuracy: 0.724200
# Epoch 32, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.722200
# Epoch 32, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.733000
# Epoch 32, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.732600
# Epoch 32, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.732600
# Epoch 33, CIFAR-10 Batch 1:  Epoch Loss:     0.0021 Validation Accuracy: 0.726800
# Epoch 33, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.736800
# Epoch 33, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.729000
# Epoch 33, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.734800
# Epoch 33, CIFAR-10 Batch 5:  Epoch Loss:     0.0021 Validation Accuracy: 0.732400
# Epoch 34, CIFAR-10 Batch 1:  Epoch Loss:     0.0006 Validation Accuracy: 0.712000
# Epoch 34, CIFAR-10 Batch 2:  Epoch Loss:     0.0015 Validation Accuracy: 0.715800
# Epoch 34, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.727400
# Epoch 34, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.734800
# Epoch 34, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.737200
# Epoch 35, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.733200
# Epoch 35, CIFAR-10 Batch 2:  Epoch Loss:     0.0018 Validation Accuracy: 0.733800
# Epoch 35, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.729800
# Epoch 35, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.736800
# Epoch 35, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.739400
# Epoch 36, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.729800
# Epoch 36, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.725400
# Epoch 36, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.727400
# Epoch 36, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.740800
# Epoch 36, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.743800
# Epoch 37, CIFAR-10 Batch 1:  Epoch Loss:     0.0022 Validation Accuracy: 0.726800
# Epoch 37, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.731800
# Epoch 37, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.731000
# Epoch 37, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.731200
# Epoch 37, CIFAR-10 Batch 5:  Epoch Loss:     0.0101 Validation Accuracy: 0.743200
# Epoch 38, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.731400
# Epoch 38, CIFAR-10 Batch 2:  Epoch Loss:     0.0006 Validation Accuracy: 0.731000
# Epoch 38, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.734000
# Epoch 38, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.730800
# Epoch 38, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.734600
# Epoch 39, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.734800
# Epoch 39, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.728400
# Epoch 39, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.726000
# Epoch 39, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.739600
# Epoch 39, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.735600
# Epoch 40, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.736000
# Epoch 40, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.730200
# Epoch 40, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.731200
# Epoch 40, CIFAR-10 Batch 4:  Epoch Loss:     0.0008 Validation Accuracy: 0.736600
# Epoch 40, CIFAR-10 Batch 5:  Epoch Loss:     0.0005 Validation Accuracy: 0.726000
# Epoch 41, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.737800
# Epoch 41, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.727400
# Epoch 41, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.717200
# Epoch 41, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.737000
# Epoch 41, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.733800
# Epoch 42, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.739600
# Epoch 42, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.730000
# Epoch 42, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.724000
# Epoch 42, CIFAR-10 Batch 4:  Epoch Loss:     0.0020 Validation Accuracy: 0.727200
# Epoch 42, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.739600
# Epoch 43, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.729600
# Epoch 43, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.731000
# Epoch 43, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.733200
# Epoch 43, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.723200
# Epoch 43, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.742600
# Epoch 44, CIFAR-10 Batch 1:  Epoch Loss:     0.0020 Validation Accuracy: 0.739000
# Epoch 44, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.732600
# Epoch 44, CIFAR-10 Batch 3:  Epoch Loss:     0.0016 Validation Accuracy: 0.727200
# Epoch 44, CIFAR-10 Batch 4:  Epoch Loss:     0.0018 Validation Accuracy: 0.723600
# Epoch 44, CIFAR-10 Batch 5:  Epoch Loss:     0.0006 Validation Accuracy: 0.732200
# Epoch 45, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.727800
# Epoch 45, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.721600
# Epoch 45, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.737600
# Epoch 45, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.724400
# Epoch 45, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.730200
# Epoch 46, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.730600
# Epoch 46, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.730200
# Epoch 46, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.724000
# Epoch 46, CIFAR-10 Batch 4:  Epoch Loss:     0.0030 Validation Accuracy: 0.734600
# Epoch 46, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.727000
# Epoch 47, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.734800
# Epoch 47, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.726200
# Epoch 47, CIFAR-10 Batch 3:  Epoch Loss:     0.0010 Validation Accuracy: 0.727200
# Epoch 47, CIFAR-10 Batch 4:  Epoch Loss:     0.0005 Validation Accuracy: 0.721800
# Epoch 47, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.739200
# Epoch 48, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.732400
# Epoch 48, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.728200
# Epoch 48, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.736400
# Epoch 48, CIFAR-10 Batch 4:  Epoch Loss:     0.0061 Validation Accuracy: 0.716200
# Epoch 48, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.731200
# Epoch 49, CIFAR-10 Batch 1:  Epoch Loss:     0.0008 Validation Accuracy: 0.745400
# Epoch 49, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.734000
# Epoch 49, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.738800
# Epoch 49, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.730000
# Epoch 49, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.730000
# Epoch 50, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.734000
# Epoch 50, CIFAR-10 Batch 2:  Epoch Loss:     0.0009 Validation Accuracy: 0.728400
# Epoch 50, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.736600
# Epoch 50, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.726000
# Epoch 50, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.728000
# Epoch 51, CIFAR-10 Batch 1:  Epoch Loss:     0.0008 Validation Accuracy: 0.736200
# Epoch 51, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.735400
# Epoch 51, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.736000
# Epoch 51, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.735600
# Epoch 51, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.738400
# Epoch 52, CIFAR-10 Batch 1:  Epoch Loss:     0.0007 Validation Accuracy: 0.738400
# Epoch 52, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.739000
# Epoch 52, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.739000
# Epoch 52, CIFAR-10 Batch 4:  Epoch Loss:     0.0066 Validation Accuracy: 0.736400
# Epoch 52, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.741000
# Epoch 53, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.735400
# Epoch 53, CIFAR-10 Batch 2:  Epoch Loss:     0.0009 Validation Accuracy: 0.731800
# Epoch 53, CIFAR-10 Batch 3:  Epoch Loss:     0.0005 Validation Accuracy: 0.729600
# Epoch 53, CIFAR-10 Batch 4:  Epoch Loss:     0.0010 Validation Accuracy: 0.735400
# Epoch 53, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.739200
# Epoch 54, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.736400
# Epoch 54, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.737000
# Epoch 54, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.734400
# Epoch 54, CIFAR-10 Batch 4:  Epoch Loss:     0.0009 Validation Accuracy: 0.741600
# Epoch 54, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.741200
# Epoch 55, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.744200
# Epoch 55, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.746200
# Epoch 55, CIFAR-10 Batch 3:  Epoch Loss:     0.0037 Validation Accuracy: 0.734200
# Epoch 55, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.743800
# Epoch 55, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.742800
# Epoch 56, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.735800
# Epoch 56, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.738200
# Epoch 56, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.734000
# Epoch 56, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.733800
# Epoch 56, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.739600
# Epoch 57, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.747400
# Epoch 57, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.739800
# Epoch 57, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.739600
# Epoch 57, CIFAR-10 Batch 4:  Epoch Loss:     0.0004 Validation Accuracy: 0.741800
# Epoch 57, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.742800
# Epoch 58, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.740800
# Epoch 58, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.738000
# Epoch 58, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.736000
# Epoch 58, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.736400
# Epoch 58, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.742400
# Epoch 59, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.743000
# Epoch 59, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.731000
# Epoch 59, CIFAR-10 Batch 3:  Epoch Loss:     0.0043 Validation Accuracy: 0.732800
# Epoch 59, CIFAR-10 Batch 4:  Epoch Loss:     0.0005 Validation Accuracy: 0.736000
# Epoch 59, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.742600
# Epoch 60, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.739000
# Epoch 60, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.741000
# Epoch 60, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.733400
# Epoch 60, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.742000
# Epoch 60, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.737200
# Epoch 61, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.740600
# Epoch 61, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.736000
# Epoch 61, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.735800
# Epoch 61, CIFAR-10 Batch 4:  Epoch Loss:     0.0042 Validation Accuracy: 0.748800
# Epoch 61, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.749400
# Epoch 62, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.746200
# Epoch 62, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.740200
# Epoch 62, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.741200
# Epoch 62, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.749600
# Epoch 62, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.747200
# Epoch 63, CIFAR-10 Batch 1:  Epoch Loss:     0.0007 Validation Accuracy: 0.747600
# Epoch 63, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.736400
# Epoch 63, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.743800
# Epoch 63, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.741400
# Epoch 63, CIFAR-10 Batch 5:  Epoch Loss:     0.0010 Validation Accuracy: 0.733000
# Epoch 64, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.749400
# Epoch 64, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.739800
# Epoch 64, CIFAR-10 Batch 3:  Epoch Loss:     0.0005 Validation Accuracy: 0.745800
# Epoch 64, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.743000
# Epoch 64, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.755000
# Epoch 65, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.743400
# Epoch 65, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.744600
# Epoch 65, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 65, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.749200
# Epoch 65, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.756400
# Epoch 66, CIFAR-10 Batch 1:  Epoch Loss:     0.0012 Validation Accuracy: 0.734400
# Epoch 66, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 66, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.742200
# Epoch 66, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 66, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.739600
# Epoch 67, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.746200
# Epoch 67, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.740200
# Epoch 67, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.736000
# Epoch 67, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.742000
# Epoch 67, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.740200
# Epoch 68, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.738600
# Epoch 68, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.750600
# Epoch 68, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.738800
# Epoch 68, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.742000
# Epoch 68, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.742600
# Epoch 69, CIFAR-10 Batch 1:  Epoch Loss:     0.0023 Validation Accuracy: 0.735800
# Epoch 69, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.740000
# Epoch 69, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.743000
# Epoch 69, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.738800
# Epoch 69, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.755800
# Epoch 70, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.743000
# Epoch 70, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.737600
# Epoch 70, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.735200
# Epoch 70, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.745000
# Epoch 70, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.750600
# Epoch 71, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.742800
# Epoch 71, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.738800
# Epoch 71, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.738600
# Epoch 71, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.742800
# Epoch 71, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.749200
# Epoch 72, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.745800
# Epoch 72, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.741000
# Epoch 72, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.732400
# Epoch 72, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.741400
# Epoch 72, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.751200
# Epoch 73, CIFAR-10 Batch 1:  Epoch Loss:     0.0011 Validation Accuracy: 0.742200
# Epoch 73, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747000
# Epoch 73, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740600
# Epoch 73, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.739800
# Epoch 73, CIFAR-10 Batch 5:  Epoch Loss:     0.0005 Validation Accuracy: 0.734000
# Epoch 74, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.740800
# Epoch 74, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747000
# Epoch 74, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.739800
# Epoch 74, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.749000
# Epoch 74, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 75, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 75, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.744800
# Epoch 75, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.743000
# Epoch 75, CIFAR-10 Batch 4:  Epoch Loss:     0.0026 Validation Accuracy: 0.736600
# Epoch 75, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.739800
# Epoch 76, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.745800
# Epoch 76, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.740000
# Epoch 76, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.751800
# Epoch 76, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.753000
# Epoch 76, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.754400
# Epoch 77, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.740600
# Epoch 77, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.744400
# Epoch 77, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.740600
# Epoch 77, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.731800
# Epoch 77, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.741400
# Epoch 78, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.738000
# Epoch 78, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.744800
# Epoch 78, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.748600
# Epoch 78, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.741000
# Epoch 78, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.746200
# Epoch 79, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.746200
# Epoch 79, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.736200
# Epoch 79, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 79, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.738800
# Epoch 79, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.747800
# Epoch 80, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.739600
# Epoch 80, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.740400
# Epoch 80, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.738400
# Epoch 80, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.745800
# Epoch 80, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.743200
# Epoch 81, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 81, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.752200
# Epoch 81, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.744000
# Epoch 81, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.739800
# Epoch 81, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.744000
# Epoch 82, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.741600
# Epoch 82, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747000
# Epoch 82, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.740000
# Epoch 82, CIFAR-10 Batch 4:  Epoch Loss:     0.0006 Validation Accuracy: 0.740000
# Epoch 82, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.749000
# Epoch 83, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.748600
# Epoch 83, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.748600
# Epoch 83, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.742800
# Epoch 83, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.739800
# Epoch 83, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.743400
# Epoch 84, CIFAR-10 Batch 1:  Epoch Loss:     0.0008 Validation Accuracy: 0.751000
# Epoch 84, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.740600
# Epoch 84, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.743200
# Epoch 84, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.741400
# Epoch 84, CIFAR-10 Batch 5:  Epoch Loss:     0.0006 Validation Accuracy: 0.744200
# Epoch 85, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.740000
# Epoch 85, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 85, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.751800
# Epoch 85, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.746600
# Epoch 85, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.740800
# Epoch 86, CIFAR-10 Batch 1:  Epoch Loss:     0.0006 Validation Accuracy: 0.744800
# Epoch 86, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.742800
# Epoch 86, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.741400
# Epoch 86, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.744800
# Epoch 86, CIFAR-10 Batch 5:  Epoch Loss:     0.0007 Validation Accuracy: 0.735800
# Epoch 87, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.738800
# Epoch 87, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.736000
# Epoch 87, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.736000
# Epoch 87, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 87, CIFAR-10 Batch 5:  Epoch Loss:     0.0751 Validation Accuracy: 0.745600
# Epoch 88, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.747000
# Epoch 88, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747800
# Epoch 88, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.745400
# Epoch 88, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.744200
# Epoch 88, CIFAR-10 Batch 5:  Epoch Loss:     0.0023 Validation Accuracy: 0.743600
# Epoch 89, CIFAR-10 Batch 1:  Epoch Loss:     0.0008 Validation Accuracy: 0.746800
# Epoch 89, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.737600
# Epoch 89, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740800
# Epoch 89, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.735400
# Epoch 89, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 90, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.742800
# Epoch 90, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.750800
# Epoch 90, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 90, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.742000
# Epoch 90, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.750200
# Epoch 91, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.749400
# Epoch 91, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.744600
# Epoch 91, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.732200
# Epoch 91, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.752400
# Epoch 91, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.743800
# Epoch 92, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.738600
# Epoch 92, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.745800
# Epoch 92, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.744800
# Epoch 92, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.736800
# Epoch 92, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.743400
# Epoch 93, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.740000
# Epoch 93, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.742800
# Epoch 93, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.737600
# Epoch 93, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.747400
# Epoch 93, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.744800
# Epoch 94, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.736800
# Epoch 94, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.735800
# Epoch 94, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.737400
# Epoch 94, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.746600
# Epoch 94, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.755200
# Epoch 95, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.740000
# Epoch 95, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.736800
# Epoch 95, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 95, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 95, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.744400
# Epoch 96, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.738400
# Epoch 96, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.743600
# Epoch 96, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740600
# Epoch 96, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.745800
# Epoch 96, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.751600
# Epoch 97, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.739400
# Epoch 97, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.749400
# Epoch 97, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.737600
# Epoch 97, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.751200
# Epoch 97, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.750800
# Epoch 98, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.745000
# Epoch 98, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.725600
# Epoch 98, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.737600
# Epoch 98, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.737600
# Epoch 98, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.746800
# Epoch 99, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.741800
# Epoch 99, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.742200
# Epoch 99, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740600
# Epoch 99, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.744200
# Epoch 99, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.747800
# Epoch 100, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.747400
# Epoch 100, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 100, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.746600
# Epoch 100, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.742200
# Epoch 100, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.735600

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.72802734375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
